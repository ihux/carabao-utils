# %%
# package reload demo

import importlib

# %%
# if you want a python cell to reload a module before usage
# => call importlib.reload()

#from carabao import screen
import carabao
import carabao.screen
importlib.reload(carabao.screen)  # reload module
from carabao.screen import Monitor

mon = Monitor(1,1)
mon.hello()
# Out:
# hello, monitor
