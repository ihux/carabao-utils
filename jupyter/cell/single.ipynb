# %%
# setup neural playground
import carabao
import carabao.screen
import carabao.cell

import importlib
importlib.reload(carabao)         # reload module
importlib.reload(carabao.screen)  # reload module
importlib.reload(carabao.cell)    # reload module
# Out:
# <module 'carabao.cell' from '/Users/hux/Bluenetics/Git/Neural/carabao-utils/venv/lib/python3.8/site-packages/carabao/cell.py'>

# %%
# single: display of a single cell

from carabao.screen import Monitor
from carabao.cell import Cell,toy
from numpy import ones

mon = Monitor(m=1,n=3)
k,g,K,P = toy('cell')
cell = Cell(mon,k,g,K,P)
cell.plot(i=0,j=0)    # plot at monitor location i,j

cell.u = cell.y = cell.x = cell.b = 1
cell.plot(i=0,j=1)    # plot at monitor location i,j

q=[1,0,1,0];  V = ones((2,5));  Q=(cell.P >= 0.5)*V 
cell.plot(0,2,q,Q)

# %%
help(Cell)
# Out:
# Help on class Cell in module carabao.cell:
#
# class Cell(builtins.object)
#  |  Cell(mon, k, g, K, P)
#  |
#  |  Cell: class Cell - modelling cell algorithm
#  |
#  |     from carabao.screen import Monitor
#  |     from carabao.cell import Cell
#  |
#  |     mon = Monitor(4,10)
#  |     k,g,K,P = Toy('cell')
#  |
#  |     cell = Cell(mon,k,g,K,P)
#  |     cell.u = cell.y = cell.x = cell.b = 1
#  |     cell.plot(i=0,j=0)    # plot at monitor location i,j
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, mon, k, g, K, P)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  burst(self, c)
#  |
#  |  config(self, k, g, K)
#  |
#  |  learn(self, Q)
#  |
#  |  phase(self, i, u, c)
#  |
#  |  phase1(self, u, c)
#  |
#  |  phase2(self, u, c)
#  |
#  |  phase3(self, u, c)
#  |
#  |  plot(self, i=None, j=None, q=None, Q=None)
#  |
#  |  select(self, c, K)
#  |
#  |  transition(self)
#  |
#  |  update(self, c)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
