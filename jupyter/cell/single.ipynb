# %%
# single: display of a single cell

from carabao.screen import Monitor 
from carabao.cell import Cell,toy 
from numpy import ones

mon = Monitor(m=1,n=3) 
k,g,K,P,c = toy('cell') 
cell = Cell(mon,k,g,K,P) 
cell.plot(i=0,j=0) # plot at monitor location i,j 
mon.xlabel(1,'<INIT>')

cell.u = cell.y = cell.x = cell.b = u = 1 

cell.plot(i=0,j=1) # plot at monitor location i,j 
mon.xlabel(2,'BURST & ACTIVE')

v = [1,0,1,0];
E = (W:=(cell.P >= 0.5))*(V:=ones((2,5))) 

cell.s = cell.spike(u,E,theta=2)
cell.plot(0,2,v,W,E)
mon.xlabel(3,'SPIKING')

# %%
help(Cell)
# Out:
# Help on class Cell in module carabao.cell:
#
# class Cell(builtins.object)
#  |  Cell(mon, k, g, K, P)
#  |
#  |  Cell: class Cell - modelling HTM cell algorithm
#  |
#  |      from carabao.screen import Monitor
#  |      from carabao.cell import Cell,toy
#  |      from numpy import ones
#  |
#  |      mon = Monitor(m=1,n=3)
#  |      k,g,K,P,c = toy('cell')
#  |      cell = Cell(mon,k,g,K,P)
#  |      cell.plot(i=0,j=0)    # plot at monitor location i,j
#  |
#  |      cell.u = cell.y = cell.x = cell.b = 1
#  |      cell.plot(i=0,j=1)    # plot at monitor location i,j
#  |
#  |      v = [1,0,1,0];  V = ones((2,5));  E = (cell.P >= 0.5)*V
#  |      cell.plot(0,2,v,E)
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, mon, k, g, K, P)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  config(self, k, g, K)
#  |
#  |  group(self, c, g)
#  |
#  |  learn(self, E)
#  |
#  |  phase(self, ph, u, c)
#  |
#  |  phase1(self, u, c)
#  |
#  |  phase2(self, u, c)
#  |
#  |  phase3(self, u, c)
#  |
#  |  plot(self, i=None, j=None, v=None, W=None, E=None)
#  |
#  |  select(self, c, K)
#  |
#  |  spike(self, u, E, theta)
#  |
#  |  transition(self)
#  |
#  |  update(self, c)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
